# %% [markdown]
# # California Housing Prices - Clustering
#
# The aim of this workbook is to use KMeans to aggregate the California Housing Prices Dataset based on a variety of pairwise factors.
#
# - url : https://www.kaggle.com/datasets/camnugent/california-housing-prices
#
# We will be using the elbow method to determine the optimal k using sum of squared distances (inertia).

# %% [markdown]
# ## Lib Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# # Data Loading

# %%
housing_df = pd.read_csv('housing.csv')

# %%
housing_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_df.isna().sum() * 100 / len(housing_df)
# Out:
# longitude             0.000000
# latitude              0.000000
# housing_median_age    0.000000
# total_rooms           0.000000
# total_bedrooms        1.002907
# population            0.000000
# households            0.000000
# median_income         0.000000
# median_house_value    0.000000
# ocean_proximity       0.000000
# dtype: float64

# %% [markdown]
# So there only seem to be missing entries for total_bedrooms, and the missing values account for 1.% of values, which is insignificant. I'm going to quickly review the object column ocean_property to make sure there aren't any missing values there either.

# %%
housing_df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# Seems fine so I will drop all missing values from the dataframe.

# %%
housing_df.dropna(inplace=True)
housing_df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
housing_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# Now I am going to have a review of the numerical features.

# %%
NUMERICAL_COLS = [col for col in housing_df.columns if housing_df[col].dtype != 'object']

# %%
housing_df[NUMERICAL_COLS].describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20433.000000
# mean        206864.413155
# std         115435.667099
# min          14999.000000
# 25%         119500.000000
# 50%         179700.000000
# 75%         264700.000000
# max         500001.000000

# %%
housing_df[NUMERICAL_COLS].hist(bins=20, figsize=(10, 10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# Alot of the numerical columns are exhibiting positive skewness, with the mode value being less than the mean. As such the dataset will have to be normalized prior to any clustering.

# %% [markdown]
# ## 2. EDA

# %% [markdown]
# __Latitude vs Longitude Scatter__

# %%
plt.scatter(housing_df['latitude'], housing_df['longitude'])

# %% [markdown]
# __Median Income vs Median House Value__

# %%
plt.scatter(housing_df['median_income'], housing_df['median_house_value'])

# %%
plt.scatter(housing_df['median_house_value'], housing_df['total_bedrooms'])

# %% [markdown]
# __A Note On Feature Scaling__
#
# The k-means algorithm is sensitive to scale. Given this, the last two Clustering Pairs will need to be scaled as their values are not directly comparable.

# %% [markdown]
# ## 3. Clustering

# %% [markdown]
# __Clustering Helpers__

# %%
def plot_n_clusters_vs_inertia(X, cluster_cols):
    """_summary_

    Args:
        X (_type_): _description_
        cluster_cols (_type_): _description_
    """
    assert(len(cluster_cols) == 2)
    n_clusters = list(range(1, 15))
    inertias = []

    for cluster in n_clusters:
        k_means = KMeans(n_clusters=cluster)
        k_means.fit(X)
        inertias.append(k_means.inertia_)

    fig, ax = plt.subplots()
    ax.plot(n_clusters, inertias, marker='x')
    ax.set(xlabel='N Clusters', ylabel="Inertia", title=f"N Clusters vs Inertia for {cluster_cols[0]} and {cluster_cols[1]}")
    plt.show()

def display_cluster(x, km, num_clusters):
    color = 'brgcmky'
    
    for i in range(num_clusters):
        labels1 = x.iloc[km.labels_ == i, 0]
        labels2 = x.iloc[km.labels_ == i, 1]
        centers1 = km.cluster_centers_[i][0]
        centers2 = km.cluster_centers_[i][1]
        color_index = i % len(color)
        plt.scatter(labels1, labels2, c=color[color_index], alpha=0.5, s=20)
        plt.scatter(centers1, centers2, c=color[color_index], marker='x', s=100)

# %% [markdown]
# ### 3.1 Latitude and Longitude Clustering

# %%
CLUSTERING_COLS = ['latitude', 'longitude']

# %%
X = housing_df[CLUSTERING_COLS]

# %%
X.head()
# Out:
#    latitude  longitude
# 0     37.88    -122.23
# 1     37.86    -122.22
# 2     37.85    -122.24
# 3     37.85    -122.25
# 4     37.85    -122.25

# %% [markdown]
# Determining the optimal n_clusters for latitude and longitude.

# %%
plot_n_clusters_vs_inertia(X, CLUSTERING_COLS)

# %% [markdown]
# So the optimal n_cluster value for latitude and longitude appears to be around 6.

# %%
NUM_CLUSTERS = 7

# %%
km = KMeans(NUM_CLUSTERS)
km.fit(X)
# Out:
# KMeans(n_clusters=7)

# %%
display_cluster(x=X, km=km, num_clusters=NUM_CLUSTERS)

# %%
X['clusters'] = km.labels_
X['median_income'] = housing_df['median_income']
# Out:
# /tmp/ipykernel_24625/1362094699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['clusters'] = km.labels_
# /tmp/ipykernel_24625/1362094699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['median_income'] = housing_df['median_income']

# %%
X.head()
# Out:
#    latitude  longitude  clusters  median_income
# 0     37.88    -122.23         1         8.3252
# 1     37.86    -122.22         1         8.3014
# 2     37.85    -122.24         1         7.2574
# 3     37.85    -122.25         1         5.6431
# 4     37.85    -122.25         1         3.8462

# %% [markdown]
# ### 3.3 Analysis of Dataset based on Clustering

# %%
sns.catplot(x='median_income', y='clusters', data=X, height=6)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sns.catplot(x='median_income', y='clusters', data=X, height=6)
#
# File ~/dev/ai_projects/kaggle/.venv/lib/python3.10/site-packages/seaborn/categorical.py:2879, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2876     if "s" not in plot_kws:
#    2877         plot_kws["s"] = plot_kws.pop("size", 5) ** 2
# -> 2879     p.plot_strips(
#    2880         jitter=jitter,
#    2881         dodge=dodge,
#    2882         color=color,
#    2883         plot_kws=plot_kws,
#    2884     )
#    2886 elif kind == "swarm":
#    2888     warn_thresh = kwargs.pop("warn_thresh", .05)
#
# File ~/dev/ai_projects/kaggle/.venv/lib/python3.10/site-packages/seaborn/categorical.py:511, in _CategoricalPlotter.plot_strips(self, jitter, dodge, color, plot_kws)
#     508 sub_data[self.orient] = adjusted_data
#     509 self._invert_scale(ax, sub_data)
# --> 511 points = ax.scatter(sub_data["x"], sub_data["y"], color=color, **plot_kws)
#     512 if "hue" in self.variables:
#     513     points.set_facecolors(self._hue_map(sub_data["hue"]))
#
# File ~/dev/ai_projects/kaggle/.venv/lib/python3.10/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/dev/ai_projects/kaggle/.venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4914, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4911     if self._ymargin < 0.05 and x.size > 0:
#    4912         self.set_ymargin(0.05)
# -> 4914 self.add_collection(collection)
#    4915 self._request_autoscale_view()
#    4917 return collection
#
# File ~/dev/ai_projects/kaggle/.venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:2298, in _AxesBase.add_collection(self, collection, autolim)
#    2293     collection.set_clip_path(self.patch)
#    2295 if autolim:
#    2296     # Make sure viewLim is not stale (mostly to match
#    2297     # pre-lazy-autoscale behavior, which is not really better).
# -> 2298     self._unstale_viewLim()
#    2299     datalim = collection.get_datalim(self.transData)
#    2300     points = datalim.get_points()
#
# File ~/dev/ai_projects/kaggle/.venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:847, in _AxesBase._unstale_viewLim(self)
#     845     for ax in self._shared_axes[name].get_siblings(self):
#     846         ax._stale_viewlims[name] = False
# --> 847 self.autoscale_view(**{f"scale{name}": scale
#     848                        for name, scale in need_scale.items()})
#
# File ~/dev/ai_projects/kaggle/.venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:2922, in _AxesBase.autoscale_view(self, tight, scalex, scaley)
#    2920 if self.use_sticky_edges:
#    2921     if self._xmargin and scalex and self.get_autoscalex_on():
# -> 2922         x_stickies = np.sort(np.concatenate([
#    2923             artist.sticky_edges.x
#    2924             for ax in self._shared_axes["x"].get_siblings(self)
#    2925             for artist in ax.get_children()]))
#    2926     if self._ymargin and scaley and self.get_autoscaley_on():
#    2927         y_stickies = np.sort(np.concatenate([
#    2928             artist.sticky_edges.y
#    2929             for ax in self._shared_axes["y"].get_siblings(self)
#    2930             for artist in ax.get_children()]))
#
# File ~/dev/ai_projects/kaggle/.venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:2922, in <listcomp>(.0)
#    2920 if self.use_sticky_edges:
#    2921     if self._xmargin and scalex and self.get_autoscalex_on():
# -> 2922         x_stickies = np.sort(np.concatenate([
#    2923             artist.sticky_edges.x
#    2924             for ax in self._shared_axes["x"].get_siblings(self)
#    2925             for artist in ax.get_children()]))
#    2926     if self._ymargin and scaley and self.get_autoscaley_on():
#    2927         y_stickies = np.sort(np.concatenate([
#    2928             artist.sticky_edges.y
#    2929             for ax in self._shared_axes["y"].get_siblings(self)
#    2930             for artist in ax.get_children()]))
#
# KeyboardInterrupt:
