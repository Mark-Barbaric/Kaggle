# %% [markdown]
# # Disaster Tweets Classification
#
# Summary: Goal is to determine which tweets are about real disasters or not
# Dataset: https://www.kaggle.com/competitions/nlp-getting-started/leaderboard
#
# The goal of this initial workbook is to complete the EDA to further investigate the data and potential features within the dataset.

# %% [markdown]
# ## Lib Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from nltk.corpus import stopwords
import preprocessor as p

ENGLISH_STOPWORDS = set(stopwords.words('english'))

# %%
RANDOM_STATE = 12

# %% [markdown]
# ## Train / Test Dataset Loading and Analysis

# %% [markdown]
# **Train Dataset Analysis**

# %%
train_df = pd.read_csv('train.csv')
train_df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
train_df.isna().sum() * 100 / len(train_df)
# Out:
# id           0.000000
# keyword      0.801261
# location    33.272035
# text         0.000000
# target       0.000000
# dtype: float64

# %% [markdown]
# Seem to be missing alot of values from keywords and location within the training dataset.

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %% [markdown]
# Now I am going to investigate whether there are any differences in distribution of target class between the missing and non missing location subsets of the training dataframe.

# %%
train_df[train_df['location'].isna()]['target'].value_counts(normalize=True)
# Out:
# target
# 0    0.575602
# 1    0.424398
# Name: proportion, dtype: float64

# %%
train_df[~train_df['location'].isna()]['target'].value_counts(normalize=True)
# Out:
# target
# 0    0.567717
# 1    0.432283
# Name: proportion, dtype: float64

# %% [markdown]
# It doesn't look like there are any substantial differences, which is quite positive.

# %% [markdown]
# **Test Dataframe Analysis**

# %%
test_df.isna().sum() * 100 / len(test_df)
# Out:
# id           0.000000
# keyword      0.796813
# location    33.864542
# text         0.000000
# dtype: float64

# %% [markdown]
# The testing dataset has similar missing data, whereby over 33% of locations are missing from the dataset.

# %%
train_df['target'].value_counts(normalize=True)
# Out:
# target
# 0    0.57034
# 1    0.42966
# Name: proportion, dtype: float64

# %% [markdown]
# ### Keyword Analysis
#
# Initial observation is that keyword represents a single word or 'category' for the tweet.

# %%
missing_keyword_mask = (train_df['keyword'].isna())

# %%
keyword_train = train_df[~missing_keyword_mask]
keyword_train
# Out:
#          id  keyword                       location  \
# 31       48   ablaze                     Birmingham
# 32       49   ablaze  Est. September 2012 - Bristol
# 33       50   ablaze                         AFRICA
# 34       52   ablaze               Philadelphia, PA
# 35       53   ablaze                     London, UK
# ...     ...      ...                            ...
# 7578  10830  wrecked                            NaN
# 7579  10831  wrecked              Vancouver, Canada
# 7580  10832  wrecked                        London
# 7581  10833  wrecked                        Lincoln
# 7582  10834  wrecked                            NaN
#
#                                                    text  target
# 31    @bbcmtd Wholesale Markets ablaze http://t.co/l...       1
# 32    We always try to bring the heavy. #metal #RT h...       0
# 33    #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 34                   Crying out for more! Set me ablaze       0
# 35    On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# ...                                                 ...     ...
# 7578   @jt_ruff23 @cameronhacker and I wrecked you both       0
# 7579  Three days off from work and they've pretty mu...       0
# 7580  #FX #forex #trading Cramer: Iger's 3 words tha...       0
# 7581  @engineshed Great atmosphere at the British Li...       0
# 7582  Cramer: Iger's 3 words that wrecked Disney's s...       0
#
# [7552 rows x 5 columns]

# %%
keyword_train['keyword'].value_counts()
# Out:
# keyword
# fatalities               45
# deluge                   42
# armageddon               42
# damage                   41
# body%20bags              41
#                          ..
# forest%20fire            19
# epicentre                12
# threat                   11
# inundation               10
# radiation%20emergency     9
# Name: count, Length: 221, dtype: int64

# %% [markdown]
# ### Location Analysis

# %%
missing_location_mask = (train_df['location'].isna())

# %%
location_train = train_df[~missing_location_mask]
location_train.head()
# Out:
#     id keyword                       location  \
# 31  48  ablaze                     Birmingham
# 32  49  ablaze  Est. September 2012 - Bristol
# 33  50  ablaze                         AFRICA
# 34  52  ablaze               Philadelphia, PA
# 35  53  ablaze                     London, UK
#
#                                                  text  target
# 31  @bbcmtd Wholesale Markets ablaze http://t.co/l...       1
# 32  We always try to bring the heavy. #metal #RT h...       0
# 33  #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 34                 Crying out for more! Set me ablaze       0
# 35  On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0

# %%
location_train['location'].value_counts()
# Out:
# location
# USA                   104
# New York               71
# United States          50
# London                 45
# Canada                 29
#                      ...
# Silesia, Poland         1
# Hickville, USA          1
# New York NYC            1
# Valle Del Sol           1
# todaysbigstock.com      1
# Name: count, Length: 3341, dtype: int64

# %% [markdown]
# There seems to be quite a mixture of different types of text within the location column, with some entries just being the country, some containing the city and country, and others not being a real location.

# %%
contains_comma_mask = (location_train['location'].str.find(',') != -1)

# %%
location_train[contains_comma_mask]['location'].value_counts()
# Out:
# location
# Los Angeles, CA                   26
# Washington, DC                    21
# Chicago, IL                       18
# California, USA                   15
# New York, NY                      15
#                                   ..
# Arlington, VA and DC               1
# Durban, South Africa               1
# Kalamazoo, Michigan                1
# Washington DC / Nantes, France     1
# ÌÏT: 33.209923,-87.545328          1
# Name: count, Length: 1305, dtype: int64

# %% [markdown]
# I'm going to need to find a better way of analysing the makeup of this location column....

# %% [markdown]
# ### Text Analysis

# %% [markdown]
# After some investigation and review of other tweets, it is apparent the the text can contains any of the below features:
#
# * 1. tags: any text starting with '#' will contain tags
# * 2. user_tags: any text starting with @ represents a user tag
# * 3. urls: text starting with https://, http:// etc contain urls
# * 4. retweets: contains t.co?

# %%
def preprocess_text(df):
    df['text'] = df['text'].str.lower()
    df['text'] = df['text'].str.replace('[^\w\s]', ' ')
    df['text'] = df['text'].str.replace('\s\s+', ' ')
    df['text'] = df['text'].apply(p.clean)
    df['text'] = df['text'].apply(lambda x : ' '.join([w for w in x.split(' ') if w not in ENGLISH_STOPWORDS]))

# %%
train_df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
preprocess_text(train_df)

# %%
train_df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN                  deeds reason may allah forgive us
# 1   4     NaN      NaN             forest fire near la ronge sask. canada
# 2   5     NaN      NaN  residents asked 'shelter place' notified offic...
# 3   6     NaN      NaN        people receive evacuation orders california
# 4   7     NaN      NaN             got sent photo ruby smoke pours school
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## X, y and train_test_split

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split

tfid_vectorizer = TfidfVectorizer()
count_vectorizer = CountVectorizer()

# %%
X_tfid = tfid_vectorizer.fit_transform(train_df['text'])
X_count = count_vectorizer.fit_transform(train_df['text'])

# %%
y = train_df['target']

# %%
X_train_tfid, X_test_tfid, y_train_tfid, y_test_tfid = train_test_split(X_tfid, y, random_state=RANDOM_STATE, test_size=0.3)
X_train_count, X_test_count, y_train_count, y_test_count = train_test_split(X_count, y, random_state=RANDOM_STATE, test_size=0.3)

# %% [markdown]
# ## Logistic Regression Training and Evaluation

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.linear_model import LogisticRegressionCV

logistic_model = LogisticRegressionCV(
    Cs=6,
    cv=2,
    scoring='f1'
)

# %%
logistic_model.fit(X_train_tfid, y_train_tfid)
# Out:
# LogisticRegressionCV(Cs=6, cv=2)

# %%
y_pred_tfid = logistic_model.predict(X_test_tfid)

# %%
print(classification_report(y_test_tfid, y_pred_tfid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82      1336
#            1       0.77      0.67      0.72       948
#
#     accuracy                           0.78      2284
#    macro avg       0.78      0.76      0.77      2284
# weighted avg       0.78      0.78      0.78      2284

# %%
logistic_model.fit(X_train_count, y_train_count)
# Out:
# LogisticRegressionCV(Cs=6, cv=2)

# %%
y_pred_count = logistic_model.predict(X_test_count)

# %%
print(classification_report(y_test_count, y_pred_count))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.83      1336
#            1       0.82      0.64      0.72       948
#
#     accuracy                           0.79      2284
#    macro avg       0.80      0.77      0.77      2284
# weighted avg       0.79      0.79      0.78      2284

# %% [markdown]
# ## Kaggle Submission

# %%
test_df = pd.read_csv('test.csv', delimiter=',')

# %%
len(test_df)
# Out:
# 3263

# %%
test_df.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
test_df[test_df['id'] == 60]['text']
# Out:
# 19    PSA: IÛªm splitting my personalities.\n\n?? t...
# Name: text, dtype: object

# %%
preprocess_text(test_df)

# %%
test_df.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                        happened terrible car crash
# 1   2     NaN      NaN        heard different cities, stay safe everyone.
# 2   3     NaN      NaN  forest fire spot pond, geese fleeing across st...
# 3   9     NaN      NaN                               apocalypse lighting.
# 4  11     NaN      NaN                typhoon soudelor kills china taiwan

# %%
X_val = tfid_vectorizer.transform(test_df['text'])

# %%
X_val
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 24030 stored elements and shape (3263, 13464)>

# %%
y_pred_val = logistic_model.predict(X_val)

# %%
y_pred_val
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
submission_df = pd.DataFrame({'id': test_df['id'], 'target': y_pred_val})

# %%
submission_df.to_csv('submission.csv', index=False)
