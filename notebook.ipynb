# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer

pd.set_option("display.max_rows", 20)

# %%
import os
import sys

current_path = os.getcwd()
print(f"current path {current_path}")
relative_path=os.path.dirname(current_path)
print(f"root path {relative_path}")
sys.path.append(f"{relative_path}")


from lib.preprocessing import *
# Out:
# current path /home/mbarbaric/dev/python/kaggle
# root path /home/mbarbaric/dev/python

# %% [markdown]
# ## Preprocessing Methods

# %%
import re

def preprocess_test(x : str)->str:
    x = x.lower()
    x = x.strip(' ')
  #  new_word = re.sub(r'[^a-zA-Z0-9 ]+', '', new_word)
    return x

# %% [markdown]
# ## Train Data Analysis

# %%
train_data = pd.read_csv('train.csv')
train_data
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %%
train_data.isna().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
train_data['keyword'].value_counts()
# Out:
# keyword
# fatalities               45
# deluge                   42
# armageddon               42
# sinking                  41
# damage                   41
#                          ..
# forest%20fire            19
# epicentre                12
# threat                   11
# inundation               10
# radiation%20emergency     9
# Name: count, Length: 221, dtype: int64

# %% [markdown]
# ### Text Column Analysis

# %%
text=train_data['text'].apply(lambda x : preprocess_text(x))
text
# Out:
# 0       our deeds are the reason of this earthquake ma...
# 1                   forest fire near la ronge sask canada
# 2       all residents asked to shelter in place are be...
# 3       13000 people receive wildfires evacuation orde...
# 4       just got sent this photo from ruby alaska as s...
#                               ...
# 7608    two giant cranes holding a bridge collapse int...
# 7609    ariaahrary thetawniest the out of control wild...
# 7610    m194 0104 utc5km s of volcano hawaii httptcozd...
# 7611    police investigating after an ebike collided w...
# 7612    the latest more homes razed by northern califo...
# Name: text, Length: 7613, dtype: object

# %%
text_list=text.to_list()
text_list
words = [[i,w] for i,sentence in enumerate(text_list) for w in sentence.split(' ') if w]
words
# Out:
# [[0, 'our'],
#  [0, 'deeds'],
#  [0, 'are'],
#  [0, 'the'],
#  [0, 'reason'],
#  [0, 'of'],
#  [0, 'this'],
#  [0, 'earthquake'],
#  [0, 'may'],
#  [0, 'allah'],
#  [0, 'forgive'],
#  [0, 'us'],
#  [0, 'all'],
#  [1, 'forest'],
#  [1, 'fire'],
#  [1, 'near'],
#  [1, 'la'],
#  [1, 'ronge'],
#  [1, 'sask'],
#  [1, 'canada'],
#  [2, 'all'],
#  [2, 'residents'],
#  [2, 'asked'],
#  [2, 'to'],
#  [2, 'shelter'],
#  [2, 'in'],
#  [2, 'place'],
#  [2, 'are'],
#  [2, 'being'],
#  [2, 'notified'],
#  [2, 'by'],
#  [2, 'officers'],
#  [2, 'no'],
#  [2, 'other'],
#  [2, 'evacuation'],
#  [2, 'or'],
#  [2, 'shelter'],
#  [2, 'in'],
#  [2, 'place'],
#  [2, 'orders'],
#  [2, 'are'],
#  [2, 'expected'],
#  [3, '13000'],
#  [3, 'people'],
#  [3, 'receive'],
#  [3, 'wildfires'],
#  [3, 'evacuation'],
#  [3, 'orders'],
#  [3, 'in'],
#  [3, 'california'],
#  [4, 'just'],
#  [4, 'got'],
#  [4, 'sent'],
#  [4, 'this'],
#  [4, 'photo'],
#  [4, 'from'],
#  [4, 'ruby'],
#  [4, 'alaska'],
#  [4, 'as'],
#  [4, 'smoke'],
#  [4, 'from'],
#  [4, 'wildfires'],
#  [4, 'pours'],
#  [4, 'into'],
#  [4, 'a'],
#  [4, 'school'],
#  [5, 'rockyfire'],
#  [5, 'update'],
#  [5, 'california'],
#  [5, 'hwy'],
#  [5, '20'],
#  [5, 'closed'],
#  [5, 'in'],
#  [5, 'both'],
#  [5, 'directions'],
#  [5, 'due'],
#  [5, 'to'],
#  [5, 'lake'],
#  [5, 'county'],
#  [5, 'fire'],
#  [5, 'cafire'],
#  [5, 'wildfires'],
#  [6, 'flood'],
#  [6, 'disaster'],
#  [6, 'heavy'],
#  [6, 'rain'],
#  [6, 'causes'],
#  [6, 'flash'],
#  [6, 'flooding'],
#  [6, 'of'],
#  [6, 'streets'],
#  [6, 'in'],
#  [6, 'manitou'],
#  [6, 'colorado'],
#  [6, 'springs'],
#  [6, 'areas'],
#  [7, 'im'],
#  [7, 'on'],
#  [7, 'top'],
#  [7, 'of'],
#  [7, 'the'],
#  [7, 'hill'],
#  [7, 'and'],
#  [7, 'i'],
#  [7, 'can'],
#  [7, 'see'],
#  [7, 'a'],
#  [7, 'fire'],
#  [7, 'in'],
#  [7, 'the'],
#  [7, 'woods'],
#  [8, 'theres'],
#  [8, 'an'],
#  [8, 'emergency'],
#  [8, 'evacuation'],
#  [8, 'happening'],
#  [8, 'now'],
#  [8, 'in'],
#  [8, 'the'],
#  [8, 'building'],
#  [8, 'across'],
#  [8, 'the'],
#  [8, 'street'],
#  [9, 'im'],
#  [9, 'afraid'],
#  [9, 'that'],
#  [9, 'the'],
#  [9, 'tornado'],
#  [9, 'is'],
#  [9, 'coming'],
#  [9, 'to'],
#  [9, 'our'],
#  [9, 'area'],
#  [10, 'three'],
#  [10, 'people'],
#  [10, 'died'],
#  [10, 'from'],
#  [10, 'the'],
#  [10, 'heat'],
#  [10, 'wave'],
#  [10, 'so'],
#  [10, 'far'],
#  [11, 'haha'],
#  [11, 'south'],
#  [11, 'tampa'],
#  [11, 'is'],
#  [11, 'getting'],
#  [11, 'flooded'],
#  [11, 'hah'],
#  [11, 'wait'],
#  [11, 'a'],
#  [11, 'second'],
#  [11, 'i'],
#  [11, 'live'],
#  [11, 'in'],
#  [11, 'south'],
#  [11, 'tampa'],
#  [11, 'what'],
#  [11, 'am'],
#  [11, 'i'],
#  [11, 'gonna'],
#  [11, 'do'],
#  [11, 'what'],
#  [11, 'am'],
#  [11, 'i'],
#  [11, 'gonna'],
#  [11, 'do'],
#  [11, 'fvck'],
#  [11, 'flooding'],
#  [12, 'raining'],
#  [12, 'flooding'],
#  [12, 'florida'],
#  [12, 'tampabay'],
#  [12, 'tampa'],
#  [12, '18'],
#  [12, 'or'],
#  [12, '19'],
#  [12, 'days'],
#  [12, 'ive'],
#  [12, 'lost'],
#  [12, 'count'],
#  [13, 'flood'],
#  [13, 'in'],
#  [13, 'bago'],
#  [13, 'myanmar'],
#  [13, 'we'],
#  [13, 'arrived'],
#  [13, 'bago'],
#  [14, 'damage'],
#  [14, 'to'],
#  [14, 'school'],
#  [14, 'bus'],
#  [14, 'on'],
#  [14, '80'],
#  [14, 'in'],
#  [14, 'multi'],
#  [14, 'car'],
#  [14, 'crash'],
#  [14, 'breaking'],
#  [15, 'whats'],
#  [15, 'up'],
#  [15, 'man'],
#  [16, 'i'],
#  [16, 'love'],
#  [16, 'fruits'],
#  [17, 'summer'],
#  [17, 'is'],
#  [17, 'lovely'],
#  [18, 'my'],
#  [18, 'car'],
#  [18, 'is'],
#  [18, 'so'],
#  [18, 'fast'],
#  [19, 'what'],
#  [19, 'a'],
#  [19, 'goooooooaaaaaal'],
#  [20, 'this'],
#  [20, 'is'],
#  [20, 'ridiculous'],
#  [21, 'london'],
#  [21, 'is'],
#  [21, 'cool'],
#  [22, 'love'],
#  [22, 'skiing'],
#  [23, 'what'],
#  [23, 'a'],
#  [23, 'wonderful'],
#  [23, 'day'],
#  [24, 'looooool'],
#  [25, 'no'],
#  [25, 'wayi'],
#  [25, 'cant'],
#  [25, 'eat'],
#  [25, 'that'],
#  [25, 'shit'],
#  [26, 'was'],
#  [26, 'in'],
#  [26, 'nyc'],
#  [26, 'last'],
#  [26, 'week'],
#  [27, 'love'],
#  [27, 'my'],
#  [27, 'girlfriend'],
#  [28, 'cooool'],
#  [29, 'do'],
#  [29, 'you'],
#  [29, 'like'],
#  [29, 'pasta'],
#  [30, 'the'],
#  [30, 'end'],
#  [31, 'bbcmtd'],
#  [31, 'wholesale'],
#  [31, 'markets'],
#  [31, 'ablaze'],
#  [31, 'httptcolhyxeohy6c'],
#  [32, 'we'],
#  [32, 'always'],
#  [32, 'try'],
#  [32, 'to'],
#  [32, 'bring'],
#  [32, 'the'],
#  [32, 'heavy'],
#  [32, 'metal'],
#  [32, 'rt'],
#  [32, 'httptcoyao1e0xngw'],
#  [33, 'africanbaze'],
#  [33, 'breaking'],
#  [33, 'newsnigeria'],
#  [33, 'flag'],
#  [33, 'set'],
#  [33, 'ablaze'],
#  [33, 'in'],
#  [33, 'aba'],
#  [33, 'httptco2nndbgwyei'],
#  [34, 'crying'],
#  [34, 'out'],
#  [34, 'for'],
#  [34, 'more'],
#  [34, 'set'],
#  [34, 'me'],
#  [34, 'ablaze'],
#  [35, 'on'],
#  [35, 'plus'],
#  [35, 'side'],
#  [35, 'look'],
#  [35, 'at'],
#  [35, 'the'],
#  [35, 'sky'],
#  [35, 'last'],
#  [35, 'night'],
#  [35, 'it'],
#  [35, 'was'],
#  [35, 'ablaze'],
#  [35, 'httptcoqqsmshaj3n'],
#  [36, 'phdsquares'],
#  [36, 'mufc'],
#  [36, 'theyve'],
#  [36, 'built'],
#  [36, 'so'],
#  [36, 'much'],
#  [36, 'hype'],
#  [36, 'around'],
#  [36, 'new'],
#  [36, 'acquisitions'],
#  [36, 'but'],
#  [36, 'i'],
#  [36, 'doubt'],
#  [36, 'they'],
#  [36, 'will'],
#  [36, 'set'],
#  [36, 'the'],
#  [36, 'epl'],
#  [36, 'ablaze'],
#  [36, 'this'],
#  [36, 'season'],
#  [37, 'inec'],
#  [37, 'office'],
#  [37, 'in'],
#  [37, 'abia'],
#  [37, 'set'],
#  [37, 'ablaze'],
#  [37, 'httptco3imaomknna'],
#  [38, 'barbados'],
#  [38, 'bridgetown'],
#  [38, 'jamaica'],
#  [38, 'two'],
#  [38, 'cars'],
#  [38, 'set'],
#  [38, 'ablaze'],
#  [38, 'santa'],
#  [38, 'cruz'],
#  [38, 'head'],
#  [38, 'of'],
#  [38, 'the'],
#  [38, 'st'],
#  [38, 'elizabeth'],
#  [38, 'police'],
#  [38, 'superintende'],
#  [38, 'httptcowdueaj8q4j'],
#  [39, 'ablaze'],
#  [39, 'for'],
#  [39, 'you'],
#  [39, 'lord'],
#  [39, 'd'],
#  [40, 'check'],
#  [40, 'these'],
#  [40, 'out'],
#  [40, 'httptcoroi2nsmejj'],
#  [40, 'httptco3tj8zjin21'],
#  [40, 'httptcoyduixefipe'],
#  [40, 'httptcolxtjc87kls'],
#  [40, 'nsfw'],
#  [41, 'on'],
#  [41, 'the'],
#  [41, 'outside'],
#  [41, 'youre'],
#  [41, 'ablaze'],
#  [41, 'and'],
#  [41, 'alivebut'],
#  [41, 'youre'],
#  [41, 'dead'],
#  [41, 'inside'],
#  [42, 'had'],
#  [42, 'an'],
#  [42, 'awesome'],
#  [42, 'time'],
#  [42, 'visiting'],
#  [42, 'the'],
#  [42, 'cfc'],
#  [42, 'head'],
#  [42, 'office'],
#  [42, 'the'],
#  [42, 'ancop'],
#  [42, 'site'],
#  [42, 'and'],
#  [42, 'ablaze'],
#  [42, 'thanks'],
#  [42, 'to'],
#  [42, 'tita'],
#  [42, 'vida'],
#  [42, 'for'],
#  [42, 'taking'],
#  [42, 'care'],
#  [42, 'of'],
#  [42, 'us'],
#  [43, 'soooo'],
#  [43, 'pumped'],
#  [43, 'for'],
#  [43, 'ablaze'],
#  [43, 'southridgelife'],
#  [44, 'i'],
#  [44, 'wanted'],
#  [44, 'to'],
#  [44, 'set'],
#  [44, 'chicago'],
#  [44, 'ablaze'],
#  [44, 'with'],
#  [44, 'my'],
#  [44, 'preaching'],
#  [44, 'but'],
#  [44, 'not'],
#  [44, 'my'],
#  [44, 'hotel'],
#  [44, 'httptcoo9qknbfofx'],
#  [45, 'i'],
#  [45, 'gained'],
#  [45, '3'],
#  [45, 'followers'],
#  [45, 'in'],
#  [45, 'the'],
#  [45, 'last'],
#  [45, 'week'],
#  [45, 'you'],
#  [45, 'know'],
#  [45, 'your'],
#  [45, 'stats'],
#  [45, 'and'],
#  [45, 'grow'],
#  [45, 'with'],
#  [45, 'httptcotiyulif5c6'],
#  [46, 'how'],
#  [46, 'the'],
#  [46, 'west'],
#  [46, 'was'],
#  [46, 'burned'],
#  [46, 'thousands'],
#  [46, 'of'],
#  [46, 'wildfires'],
#  [46, 'ablaze'],
#  [46, 'in'],
#  [46, 'california'],
#  [46, 'alone'],
#  [46, 'httptcovl5tbr3wbr'],
#  [47, 'building'],
#  [47, 'the'],
#  [47, 'perfect'],
#  [47, 'tracklist'],
#  [47, 'to'],
#  [47, 'life'],
#  [47, 'leave'],
#  [47, 'the'],
#  [47, 'streets'],
#  [47, 'ablaze'],
#  [48, 'check'],
#  [48, 'these'],
#  [48, 'out'],
#  [48, 'httptcoroi2nsmejj'],
#  [48, 'httptco3tj8zjin21'],
#  [48, 'httptcoyduixefipe'],
#  [48, 'httptcolxtjc87kls'],
#  [48, 'nsfw'],
#  [49, 'first'],
#  [49, 'night'],
#  [49, 'with'],
#  [49, 'retainers'],
#  [49, 'in'],
#  [49, 'its'],
#  [49, 'quite'],
#  [49, 'weird'],
#  [49, 'better'],
#  [49, 'get'],
#  [49, 'used'],
#  [49, 'to'],
#  [49, 'it'],
#  [49, 'i'],
#  [49, 'have'],
#  [49, 'to'],
#  [49, 'wear'],
#  [49, 'them'],
#  [49, 'every'],
#  [49, 'single'],
#  [49, 'night'],
#  [49, 'for'],
#  [49, 'the'],
#  [49, 'next'],
#  [49, 'year'],
#  [49, 'at'],
#  [49, 'least'],
#  [50, 'deputies'],
#  [50, 'man'],
#  [50, 'shot'],
#  [50, 'before'],
#  [50, 'brighton'],
#  [50, 'home'],
#  [50, 'set'],
#  [50, 'ablaze'],
#  [50, 'httptcogwnrhmso8k'],
#  [51, 'man'],
#  [51, 'wife'],
#  [51, 'get'],
#  [51, 'six'],
#  [51, 'years'],
#  [51, 'jail'],
#  [51, 'for'],
#  [51, 'setting'],
#  [51, 'ablaze'],
#  [51, 'niecehttptcoev1ahoucza'],
#  [52, 'santa'],
#  [52, 'cruz'],
#  [52, 'head'],
#  [52, 'of'],
#  [52, 'the'],
#  [52, 'st'],
#  [52, 'elizabeth'],
#  [52, 'police'],
#  [52, 'superintendent'],
#  [52, 'lanford'],
#  [52, 'salmon'],
#  [52, 'has'],
#  [52, 'r'],
#  [52, 'httptcovplr5hka2u'],
#  [52, 'httptcosxhw2tnnlf'],
#  [53, 'police'],
#  [53, 'arsonist'],
#  [53, 'deliberately'],
#  [53, 'set'],
#  [53, 'black'],
#  [53, 'church'],
#  [53, 'in'],
#  [53, 'north'],
#  [53, 'carolinaablaze'],
#  [53, 'httptcopcxarbh9an'],
#  [54, 'noches'],
#  [54, 'elbestia'],
#  [54, 'alexissanchez'],
#  [54, 'happy'],
#  [54, 'to'],
#  [54, 'see'],
#  [54, 'my'],
#  [54, 'teammates'],
#  [54, 'and'],
#  [54, 'training'],
#  [54, 'hard'],
#  [54, 'goodnight'],
#  [54, 'gunners'],
#  [54, 'httptcouc4j4jhvgr'],
#  [55, 'kurds'],
#  [55, 'trampling'],
#  [55, 'on'],
#  [55, 'turkmen'],
#  [55, 'flag'],
#  [55, 'later'],
#  [55, 'set'],
#  [55, 'it'],
#  [55, 'ablaze'],
#  [55, 'while'],
#  [55, 'others'],
#  [55, 'vandalized'],
#  [55, 'offices'],
#  [55, 'of'],
#  [55, 'turkmen'],
#  [55, 'front'],
#  [55, 'in'],
#  [55, 'diyala'],
#  [55, 'httptco4izfdyc3cg'],
#  [56, 'truck'],
#  [56, 'ablaze'],
#  [56, 'r21'],
#  [56, 'voortrekker'],
#  [56, 'ave'],
#  [56, 'outside'],
#  [56, 'or'],
#  [56, 'tambo'],
#  [56, 'intl'],
#  [56, 'cargo'],
#  [56, 'section'],
#  [56, 'httptco8kscqkfkkf'],
#  [57, 'set'],
#  [57, 'our'],
#  [57, 'hearts'],
#  [57, 'ablaze'],
#  [57, 'and'],
#  [57, 'every'],
#  [57, 'city'],
#  [57, 'was'],
#  [57, 'a'],
#  [57, 'gift'],
#  [57, 'and'],
#  [57, 'every'],
#  [57, 'skyline'],
#  [57, 'was'],
#  [57, 'like'],
#  [57, 'a'],
#  [57, 'kiss'],
#  [57, 'upon'],
#  [57, 'the'],
#  [57, 'lips'],
#  [57, 'httpstcocyompz1a0z'],
#  [58, 'they'],
#  [58, 'sky'],
#  [58, 'was'],
#  [58, 'ablaze'],
#  [58, 'tonight'],
#  [58, 'in'],
#  [58, 'los'],
#  [58, 'angeles'],
#  [58, 'im'],
#  [58, 'expecting'],
#  [58, 'ig'],
#  [58, 'and'],
#  [58, 'fb'],
#  [58, 'to'],
#  [58, 'be'],
#  [58, 'filled'],
#  [58, 'with'],
#  [58, 'sunset'],
#  [58, 'shots'],
#  [58, 'if'],
#  [58, 'i'],
#  [58, 'know'],
#  [58, 'my'],
#  [58, 'peeps'],
#  [59, 'how'],
#  [59, 'the'],
#  [59, 'west'],
#  [59, 'was'],
#  [59, 'burned'],
#  [59, 'thousands'],
#  [59, 'of'],
#  [59, 'wildfires'],
#  [59, 'ablaze'],
#  [59, 'in'],
#  [59, 'california'],
#  [59, 'alone'],
#  [59, 'httptcoicsjgz9te1'],
#  [59, 'climate'],
#  [59, 'energy'],
#  [59, 'httptco9fxmn0l0bd'],
#  [60, 'revel'],
#  [60, 'in'],
#  [60, 'yours'],
#  [60, 'wmv'],
#  [60, 'videos'],
#  [60, 'by'],
#  [60, 'means'],
#  [60, 'of'],
#  [60, 'mac'],
#  [60, 'farewell'],
#  [60, 'ablaze'],
#  [60, 'wmv'],
#  [60, 'en'],
#  [60, 'route'],
#  [60, 'to'],
#  [60, 'dvd'],
#  [60, 'gtxrwm'],
#  [61, 'progressive'],
#  [61, 'greetingsin'],
#  [61, 'about'],
#  [61, 'a'],
#  [61, 'month'],
#  [61, 'students'],
#  [61, 'would'],
#  [61, 'have'],
#  [61, 'set'],
#  [61, 'their'],
#  [61, 'pens'],
#  [61, 'ablaze'],
#  [61, 'in'],
#  [61, 'the'],
#  [61, 'torch'],
#  [61, 'publications'],
#  [61, 'httptco9fxpixqujt'],
#  [62, 'rene'],
#  [62, 'ablaze'],
#  [62, 'amp'],
#  [62, 'jacinta'],
#  [62, 'secret'],
#  [62, '2k13'],
#  [62, 'fallen'],
#  [62, 'skies'],
#  [62, 'edit'],
#  [62, 'mar'],
#  [62, '30'],
#  [62, '2013'],
#  [62, 'httpstco7mlmsuzv1z'],
#  [63, 'navista7'],
#  [63, 'steve'],
#  [63, 'these'],
#  [63, 'fires'],
#  [63, 'out'],
#  [63, 'here'],
#  [63, 'are'],
#  [63, 'something'],
#  [63, 'else'],
#  [63, 'california'],
#  [63, 'is'],
#  [63, 'a'],
#  [63, 'tinderbox'],
#  [63, 'and'],
#  [63, 'this'],
#  [63, 'clown'],
#  [63, 'was'],
#  [63, 'setting'],
#  [63, 'my'],
#  [63, 'hood'],
#  [63, 'ablaze'],
#  [63, 'news24680'],
#  [64, 'nowplaying'],
#  [64, 'rene'],
#  [64, 'ablaze'],
#  [64, 'amp'],
#  [64, 'ian'],
#  [64, 'buff'],
#  [64, 'magnitude'],
#  [64, 'httptcoav2jsjfftc'],
#  [64, 'edm'],
#  [65, 'nxwestmidlands'],
#  [65, 'huge'],
#  [65, 'fire'],
#  [65, 'at'],
#  [65, 'wholesale'],
#  [65, 'markets'],
#  [65, 'ablaze'],
#  [65, 'httptcorwzbfvnxer'],
#  [66, 'ablaze'],
#  [66, 'what'],
#  [66, 'time'],
#  [66, 'does'],
#  [66, 'your'],
#  [66, 'talk'],
#  [66, 'go'],
#  [66, 'until'],
#  [66, 'i'],
#  [66, 'dont'],
#  [66, 'know'],
#  [66, 'if'],
#  [66, 'i'],
#  [66, 'can'],
#  [66, 'make'],
#  [66, 'it'],
#  [66, 'due'],
#  [66, 'to'],
#  [66, 'work'],
#  [67, 'i'],
#  [67, 'cant'],
#  [67, 'have'],
#  [67, 'kids'],
#  [67, 'cuz'],
#  [67, 'i'],
#  [67, 'got'],
#  [67, 'in'],
#  [67, 'a'],
#  [67, 'bicycle'],
#  [67, 'accident'],
#  [67, 'amp'],
#  [67, 'split'],
#  [67, 'my'],
#  [67, 'testicles'],
#  [67, 'its'],
#  [67, 'impossible'],
#  [67, 'for'],
#  [67, 'me'],
#  [67, 'to'],
#  [67, 'have'],
#  [67, 'kids'],
#  [67, 'michael'],
#  [67, 'you'],
#  [67, 'are'],
#  [67, 'the'],
#  [67, 'father'],
#  [68, 'accident'],
#  [68, 'on'],
#  [68, 'i24'],
#  [68, 'w'],
#  [68, 'nashvilletraffic'],
#  [68, 'traffic'],
#  [68, 'moving'],
#  [68, '8m'],
#  [68, 'slower'],
#  [68, 'than'],
#  [68, 'usual'],
#  [68, 'httpstco0ghk693egj'],
#  [69, 'accident'],
#  [69, 'center'],
#  [69, 'lane'],
#  [69, 'blocked'],
#  [69, 'in'],
#  [69, 'santaclara'],
#  [69, 'on'],
#  [69, 'us101'],
#  [69, 'nb'],
#  [69, 'before'],
#  [69, 'great'],
#  [69, 'america'],
#  [69, 'pkwy'],
#  [69, 'bayarea'],
#  [69, 'traffic'],
#  [69, 'httptcopmlohzurwr'],
#  [70, 'httptcogkye6gjtk5'],
#  [70, 'had'],
#  [70, 'a'],
#  [70, 'personalinjury'],
#  [70, 'accident'],
#  [70, 'this'],
#  [70, 'summer'],
#  [70, 'read'],
#  [70, 'our'],
#  [70, 'advice'],
#  [70, 'amp'],
#  [70, 'see'],
#  [70, 'how'],
#  [70, 'a'],
#  [70, 'solicitor'],
#  [70, 'can'],
#  [70, 'help'],
#  [70, 'otleyhour'],
#  [71, 'stlouis'],
#  [71, 'caraccidentlawyer'],
#  [71, 'speeding'],
#  [71, 'among'],
#  [71, 'top'],
#  [71, 'causes'],
#  [71, 'of'],
#  [71, 'teen'],
#  [71, 'accidents'],
#  [71, 'httpstcok4zomof319'],
#  [71, 'httpstcos2kxvm0cba'],
#  [71, 'car'],
#  [71, 'accident'],
#  [71, 'tee'],
#  [72, 'reported'],
#  [72, 'motor'],
#  [72, 'vehicle'],
#  [72, 'accident'],
#  [72, 'in'],
#  [72, 'curry'],
#  [72, 'on'],
#  [72, 'herman'],
#  [72, 'rd'],
#  [72, 'near'],
#  [72, 'stephenson'],
#  [72, 'involving'],
#  [72, 'an'],
#  [72, 'overturned'],
#  [72, 'vehicle'],
#  [72, 'please'],
#  [72, 'use'],
#  [72, 'httptcoybjezkurw1'],
#  [73, 'bigrigradio'],
#  [73, 'live'],
#  [73, 'accident'],
#  [73, 'awareness'],
#  [74, 'i77'],
#  [74, 'mile'],
#  [74, 'marker'],
#  [74, '31'],
#  [74, 'south'],
#  [74, 'mooresville'],
#  [74, 'iredell'],
#  [74, 'vehicle'],
#  [74, 'accident'],
#  [74, 'ramp'],
#  [74, 'closed'],
#  [74, 'at'],
#  [74, '86'],
#  [74, '118'],
#  [74, 'pm'],
#  [75, 'rt'],
#  [75, 'sleepjunkies'],
#  [75, 'sleeping'],
#  [75, 'pills'],
#  [75, 'double'],
#  [75, 'your'],
#  [75, 'risk'],
#  [75, 'of'],
#  [75, 'a'],
#  [75, 'car'],
#  [75, 'accident'],
#  [75, 'httptco7s9nm1fict'],
#  [76, 'by'],
#  [76, 'accident'],
#  [76, 'they'],
#  [76, 'knew'],
#  [76, 'what'],
#  [76, 'was'],
#  [76, 'gon'],
#  [76, 'happen'],
#  [76, 'httpstcoysxun5vceh'],
#  [77, 'traffic'],
#  [77, 'accident'],
#  [77, 'n'],
#  [77, 'cabrillo'],
#  [77, 'hwymagellan'],
#  [77, 'av'],
#  [77, 'mir'],
#  [77, '080615'],
#  [77, '110358'],
#  [78, 'i77'],
#  [78, 'mile'],
#  [78, 'marker'],
#  [78, '31'],
#  [78, 'to'],
#  [78, '40'],
#  [78, 'south'],
#  [78, 'mooresville'],
#  [78, 'iredell'],
#  [78, 'vehicle'],
#  [78, 'accident'],
#  [78, 'congestion'],
#  [78, 'at'],
#  [78, '86'],
#  [78, '118'],
#  [78, 'pm'],
#  [79, 'the'],
#  [79, 'pastor'],
#  [79, 'was'],
#  [79, 'not'],
#  [79, 'in'],
#  [79, 'the'],
#  [79, 'scene'],
#  [79, 'of'],
#  [79, 'the'],
#  [79, 'accidentwho'],
#  [79, 'was'],
#  [79, 'the'],
#  [79, 'owner'],
#  [79, 'of'],
#  [79, 'the'],
#  [79, 'range'],
#  [79, 'rover'],
#  [80, 'mom'],
#  [80, 'we'],
#  [80, 'didnt'],
#  [80, 'get'],
#  [80, 'home'],
#  [80, 'as'],
#  [80, 'fast'],
#  [80, 'as'],
#  [80, 'we'],
#  [80, 'wished'],
#  [80, 'me'],
#  [80, 'why'],
#  [80, 'is'],
#  [80, 'thatmom'],
#  [80, 'there'],
#  [80, 'was'],
#  [80, 'an'],
#  [80, 'accident'],
#  [80, 'and'],
#  [80, 'some'],
#  [80, 'truck'],
#  [80, 'spilt'],
#  [80, 'mayonnaise'],
#  [80, 'all'],
#  [80, 'over'],
#  [81, 'i'],
#  [81, 'was'],
#  [81, 'in'],
#  [81, 'a'],
#  [81, 'horrible'],
#  [81, 'car'],
#  [81, 'accident'],
#  [81, 'this'],
#  [81, 'past'],
#  [81, 'sunday'],
#  [81, 'im'],
#  [81, 'finally'],
#  [81, 'able'],
#  [81, 'to'],
#  [81, 'get'],
#  [81, 'around'],
#  [81, 'thank'],
#  [81, 'you'],
#  [81, 'god'],
#  [82, 'can'],
#  [82, 'wait'],
#  [82, 'to'],
#  [82, 'see'],
#  [82, 'how'],
#  [82, 'pissed'],
#  [82, 'donnie'],
#  [82, 'is'],
#  [82, 'when'],
#  [82, 'i'],
#  [82, 'tell'],
#  [82, 'him'],
#  [82, 'i'],
#  [82, 'was'],
#  [82, 'in'],
#  [82, 'another'],
#  [82, 'accident'],
#  [83, 'truckcrash'],
#  [83, 'overturns'],
#  [83, 'on'],
#  [83, 'fortworth'],
#  [83, 'interstate'],
#  [83, 'httptcors22lj4qfp'],
#  [83, 'click'],
#  [83, 'here'],
#  [83, 'if'],
#  [83, 'youve'],
#  [83, 'been'],
#  [83, 'in'],
#  [83, 'a'],
#  [83, 'crashgthttptcold0uniyw4k'],
#  [84, 'accident'],
#  [84, 'in'],
#  [84, 'ashville'],
#  [84, 'on'],
#  [84, 'us'],
#  ...]

# %%
word_frame=pd.DataFrame(words, columns=['sentence_id', 'token'])
word_frame
# Out:
#         sentence_id              token
# 0                 0                our
# 1                 0              deeds
# 2                 0                are
# 3                 0                the
# 4                 0             reason
# ...             ...                ...
# 110749         7612         california
# 110750         7612           wildfire
# 110751         7612                abc
# 110752         7612               news
# 110753         7612  httptcoymy4rskq3d
#
# [110754 rows x 2 columns]

# %%
word_frame.value_counts()
# Out:
# sentence_id  token
# 7472         wreck          13
# 3742         on              6
#              fire            6
# 6490         his             5
# 1064         the             5
#                             ..
# 2592         meats           1
#              italian         1
#              incinerator     1
#              food            1
# 7612         wildfire        1
# Name: count, Length: 105459, dtype: int64

# %%
none_words=word_frame.loc[word_frame['token'].str.contains('http')]
none_words
# Out:
#         sentence_id              token
# 254              31  httptcolhyxeohy6c
# 264              32  httptcoyao1e0xngw
# 273              33  httptco2nndbgwyei
# 293              35  httptcoqqsmshaj3n
# 321              37  httptco3imaomknna
# ...             ...                ...
# 110682         7607  httptco3sicroaanz
# 110683         7607  httptcoi27oa0hisp
# 110694         7608  httptcostfmbbzfb5
# 110722         7610  httptcozdtoyd8ebj
# 110753         7612  httptcoymy4rskq3d
#
# [4716 rows x 2 columns]

# %%
is_real_disaster=train_data.loc[train_data['target'] == 1]['text']
is_real_disaster
# Out:
# 0       Our Deeds are the Reason of this #earthquake M...
# 1                  Forest fire near La Ronge Sask. Canada
# 2       All residents asked to 'shelter in place' are ...
# 3       13,000 people receive #wildfires evacuation or...
# 4       Just got sent this photo from Ruby #Alaska as ...
#                               ...
# 7608    Two giant cranes holding a bridge collapse int...
# 7609    @aria_ahrary @TheTawniest The out of control w...
# 7610    M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 7611    Police investigating after an e-bike collided ...
# 7612    The Latest: More Homes Razed by Northern Calif...
# Name: text, Length: 3271, dtype: object

# %%
fake_disaster=train_data.loc[train_data['target'] == 0]['text']
fake_disaster
# Out:
# 15                                         What's up man?
# 16                                          I love fruits
# 17                                       Summer is lovely
# 18                                      My car is so fast
# 19                           What a goooooooaaaaaal!!!!!!
#                               ...
# 7581    @engineshed Great atmosphere at the British Li...
# 7582    Cramer: Iger's 3 words that wrecked Disney's s...
# 7584    These boxes are ready to explode! Exploding Ki...
# 7587                                   Sirens everywhere!
# 7593    I just heard a really loud bang and everyone i...
# Name: text, Length: 4342, dtype: object
